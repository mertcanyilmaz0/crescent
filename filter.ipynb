# %%
import pandas as pd

# %%
df = pd.read_csv("element_verileri.csv")

# %%
df = pd.DataFrame(df)

# %%
df.sort_values(by="success_score", ascending=False)
# Out:
#            He        Ne        Cl        Mg        Ti        Fe        Ag  \
# 931  0.840255  0.290909  0.650161  0.865274  0.907561  0.635443  0.993614
# 51   0.820650  0.649918  0.625970  0.964624  0.928195  0.814753  0.499513
# 739  0.689979  0.668798  0.850975  0.287487  0.664007  0.866448  0.958910
# 29   0.879475  0.878108  0.584183  1.009823  0.934459  0.766104  0.677631
# 229  0.973176  0.949640  0.722489  0.706088  0.631312  0.947789  0.815067
# ..        ...       ...       ...       ...       ...       ...       ...
# 41   0.639133  0.506037  0.795620  0.511399  0.247857  0.113575  0.641247
# 802  0.561500  0.102362  0.200294  0.326541  0.504313  0.201310  0.162519
# 397  0.418826  0.787889  0.234616  0.133085  0.930192  0.477454  0.216182
# 514  0.952450  0.474498  0.220992  0.229094  0.360071  0.147294  0.182950
# 524  0.302225  0.400435  0.700726  0.726995  0.809996  0.130909  0.208145
#
#            Ni        Si        Cu  ...         C        Cr         S  \
# ...

# %%
import matplotlib.pyplot as plt
df['success_score'].hist(bins=50)
plt.title('Distribution of success_score')
plt.show()
